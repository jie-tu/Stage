# %% [markdown]
# # Première visualisation sur les donnes OpenStreetMap

# %% [markdown]
# ### Afficher les chemins à côté d'Arc de Triomphe

# %%
import osmnx as ox

# %%
G = ox.graph_from_address('Pl. Charles de Gaulle, 75008 Paris', network_type='walk')
ox.plot_graph(G)
# Out:
# (<Figure size 576x576 with 1 Axes>, <AxesSubplot:>)

# %%
gdf = ox.geometries_from_address('Pl. Charles de Gaulle, 75008 Paris',{"highway": True})
list=[]
for i in range  (len(gdf['highway'])):
    if (gdf['highway'][i] not in list):
        list.append(gdf['highway'][i])    
print (list)
# Out:
# c:\users\jietu\appdata\local\programs\python\python39\lib\site-packages\osmnx\geometries.py:805: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   for merged_outer_linestring in list(merged_outer_linestrings):
# c:\users\jietu\appdata\local\programs\python\python39\lib\site-packages\osmnx\geometries.py:805: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   for merged_outer_linestring in list(merged_outer_linestrings):
# ...

# %%
gdf2 = ox.geometries_from_address('Pl. Charles de Gaulle, 75008 Paris',{"highway": "pedestrian"})
# Out:
# c:\users\jietu\appdata\local\programs\python\python39\lib\site-packages\osmnx\geometries.py:805: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   for merged_outer_linestring in list(merged_outer_linestrings):
# c:\users\jietu\appdata\local\programs\python\python39\lib\site-packages\osmnx\geometries.py:805: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   for merged_outer_linestring in list(merged_outer_linestrings):

# %%
gdf2.dtypes
# Out:
# highway              object
# geometry           geometry
# access               object
# foot                 object
# source               object
# name                 object
# level                object
# addr:city            object
# nodes                object
# lit                  object
# surface              object
# cycleway             object
# oneway               object
# oneway:bicycle       object
# addr:country         object
# postal_code          object
# bicycle              object
# wikidata             object
# area                 object
# alt_name             object
# ref:FR:FANTOIR       object
# old_name             object
# wikipedia            object
# name:ko              object
# maxspeed             object
# motor_vehicle        object
# source:maxspeed      object
# smoothness           object
# ways                 object
# type                 object
# dtype: object

# %%
gdf3=gdf2[['highway','geometry','name','nodes','surface','nodes','lit','maxspeed']]
gdf3
# Out:
#                          highway  \
# element_type osmid
# way          4294008  pedestrian
#              4447062  pedestrian
#              4447066  pedestrian
#              4942423  pedestrian
#              4942569  pedestrian
# ...                          ...
# relation     3808459  pedestrian
#              3808471  pedestrian
#              5781108  pedestrian
#              5802698  pedestrian
#              7849999  pedestrian
#
#                                                                geometry  \
# element_type osmid
# way          4294008  LINESTRING (2.30449 48.86914, 2.30456 48.86909...
#              4447062    LINESTRING (2.29587 48.87856, 2.29537 48.87901)
#              4447066  LINESTRING (2.29548 48.87836, 2.29566 48.87845...
#              4942423  LINESTRING (2.30845 48.87383, 2.30856 48.87390...
#              4942569    LINESTRING (2.30625 48.87846, 2.30662 48.87861)
# ...                                                                 ...
# ...

# %% [markdown]
# ### Afficher les bâtiments à côté d'Arc de Triomphe

# %%
gdf4 = ox.geometries_from_address('Pl. Charles de Gaulle, 75008 Paris',{"building": True})
list=[]
for i in range  (len(gdf4['building'])):
    if (gdf4['building'][i] not in list):
        list.append(gdf4['building'][i])    
print (list)
# Out:
# c:\users\jietu\appdata\local\programs\python\python39\lib\site-packages\osmnx\geometries.py:805: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   for merged_outer_linestring in list(merged_outer_linestrings):
# c:\users\jietu\appdata\local\programs\python\python39\lib\site-packages\osmnx\geometries.py:805: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   for merged_outer_linestring in list(merged_outer_linestrings):
# ...

# %%
fig, ax = ox.plot_footprints(gdf4)

# %%
gdf4.dtypes
# Out:
# addr:city             object
# addr:housenumber      object
# addr:postcode         object
# addr:street           object
# amenity               object
#                        ...
# ref:FR:BSPP:GRPT      object
# ref:FR:BSPP:PC_CIE    object
# source:BSPP           object
# source:tourism        object
# reservoir             object
# Length: 196, dtype: object

# %%
gdf5=gdf4[["addr:city","addr:housenumber","addr:postcode","addr:street","name","geometry","building"]]

# %%
gdf5.head(60)
# Out:
#                         addr:city addr:housenumber addr:postcode  \
# element_type osmid
# node         839122487      Paris                6         75008
#              3390717619     Paris               74         75116
#              3764948991       NaN              NaN           NaN
#              3980268306       NaN              NaN           NaN
#              3985131776       NaN              NaN           NaN
#              6801999392     Paris              234         75017
# way          48433146         NaN              NaN           NaN
#              67028278         NaN              NaN           NaN
#              67028279         NaN              NaN           NaN
#              67028282         NaN              NaN           NaN
#              67028283         NaN              NaN           NaN
#              67028284         NaN              NaN           NaN
#              67028285         NaN              NaN           NaN
# ...

# %% [markdown]
# ### Combiner les chemins et les bâtiments

# %%
img_folder = "images"
extension = "png"
size = 2400
tags = {"building": True}

def make_plot(
    place,
    point,
    network_type="walk",
    dpi=400,
    dist=1000,
):
    fp = f"./{img_folder}/{place}.{extension}"
    gdf = ox.geometries_from_point(point, tags, dist=dist)
    fig, ax = ox.plot_figure_ground(
        point=point,
        dist=dist,
        network_type=network_type,
        save=False,
        show=False,
        close=True,
    )
    fig, ax = ox.plot_footprints(
        gdf, ax=ax, filepath=fp, dpi=dpi, save=True, show=False, close=True
    )

# %%
place = "Arc de Triomphe"
point = (48.87389505514931, 2.2950432785387456)
make_plot(place, point)
# Out:
# c:\users\jietu\appdata\local\programs\python\python39\lib\site-packages\osmnx\geometries.py:805: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   for merged_outer_linestring in list(merged_outer_linestrings):
# c:\users\jietu\appdata\local\programs\python\python39\lib\site-packages\osmnx\geometries.py:805: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   for merged_outer_linestring in list(merged_outer_linestrings):
